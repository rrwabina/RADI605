# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import export as export 
import eli5
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sksurv.datasets import load_gbsg2
from sksurv.preprocessing import OneHotEncoder
from sksurv.ensemble import RandomSurvivalForest
from sksurv.datasets import load_whas500
from sksurv.tree import SurvivalTree
from sksurv.util import Surv

# %%
X, y = load_whas500()
X = X.astype(float)
estimator = SurvivalTree().fit(X, y)

# %%
export.plot_tree(estimator, feature_names = estimator.feature_names_in_, impurity = False,)
# Out:
# [Text(228.75459437086093, 210.645, 'age <= 85.5\nsamples = 500\nvalue = '),
#  Text(150.42442052980132, 197.055, 'chf <= 0.5\nsamples = 433\nvalue = '),
#  Text(78.0183774834437, 183.465, 'age <= 72.5\nsamples = 315\nvalue = '),
#  Text(28.82384105960265, 169.875, 'sysbp <= 85.0\nsamples = 204\nvalue = '),
#  Text(24.389403973509932, 156.285, 'samples = 5\nvalue = '),
#  Text(33.258278145695364, 156.285, 'hr <= 126.5\nsamples = 199\nvalue = '),
#  Text(28.82384105960265, 142.695, 'hr <= 79.5\nsamples = 194\nvalue = '),
#  Text(17.73774834437086, 129.10500000000002, 'age <= 70.5\nsamples = 103\nvalue = '),
#  Text(8.86887417218543, 115.515, 'sysbp <= 168.5\nsamples = 97\nvalue = '),
#  Text(4.434437086092715, 101.925, 'samples = 76\nvalue = '),
#  Text(13.303311258278146, 101.925, 'sysbp <= 175.0\nsamples = 21\nvalue = '),
#  Text(8.86887417218543, 88.33500000000001, 'bmi <= 27.677\nsamples = 7\nvalue = '),
#  Text(4.434437086092715, 74.745, 'samples = 3\nvalue = '),
#  Text(13.303311258278146, 74.745, 'samples = 4\nvalue = '),
#  Text(17.73774834437086, 88.33500000000001, 'samples = 14\nvalue = '),
#  Text(26.606622516556293, 115.515, 'bmi <= 25.663\nsamples = 6\nvalue = '),
#  Text(22.172185430463575, 101.925, 'samples = 3\nvalue = '),
#  Text(31.041059602649007, 101.925, 'samples = 3\nvalue = '),
#  Text(39.909933774834435, 129.10500000000002, 'diasbp <= 45.0\nsamples = 91\nvalue = '),
#  Text(35.47549668874172, 115.515, 'samples = 4\nvalue = '),
#  Text(44.34437086092715, 115.515, 'los <= 1.5\nsamples = 87\nvalue = '),
#  Text(39.909933774834435, 101.925, 'samples = 5\nvalue = '),
#  Text(48.778807947019864, 101.925, 'bmi <= 39.795\nsamples = 82\nvalue = '),
#  Text(44.34437086092715, 88.33500000000001, 'los <= 7.5\nsamples = 79\nvalue = '),
#  Text(28.82384105960265, 74.745, 'bmi <= 26.955\nsamples = 58\nvalue = '),
#  Text(24.389403973509932, 61.155, 'samples = 21\nvalue = '),
#  Text(33.258278145695364, 61.155, 'bmi <= 27.389\nsamples = 37\nvalue = '),
#  Text(28.82384105960265, 47.565, 'samples = 3\nvalue = '),
#  Text(37.69271523178808, 47.565, 'sysbp <= 186.5\nsamples = 34\nvalue = '),
#  Text(33.258278145695364, 33.974999999999994, 'cvd <= 0.5\nsamples = 30\nvalue = '),
#  Text(28.82384105960265, 20.38499999999999, 'sysbp <= 133.5\nsamples = 11\nvalue = '),
#  Text(24.389403973509932, 6.7949999999999875, 'samples = 4\nvalue = '),
#  Text(33.258278145695364, 6.7949999999999875, 'samples = 7\nvalue = '),
#  Text(37.69271523178808, 20.38499999999999, 'samples = 19\nvalue = '),
#  Text(42.12715231788079, 33.974999999999994, 'samples = 4\nvalue = '),
#  Text(59.86490066225166, 74.745, 'age <= 61.0\nsamples = 21\nvalue = '),
#  Text(50.99602649006622, 61.155, 'miord <= 0.5\nsamples = 11\nvalue = '),
#  Text(46.56158940397351, 47.565, 'samples = 8\nvalue = '),
#  Text(55.43046357615894, 47.565, 'samples = 3\nvalue = '),
#  Text(68.73377483443709, 61.155, 'hr <= 83.5\nsamples = 10\nvalue = '),
#  Text(64.29933774834437, 47.565, 'samples = 5\nvalue = '),
#  Text(73.1682119205298, 47.565, 'samples = 5\nvalue = '),
#  Text(53.213245033112585, 88.33500000000001, 'samples = 3\nvalue = '),
#  Text(37.69271523178808, 142.695, 'samples = 5\nvalue = '),
#  Text(127.21291390728477, 169.875, 'bmi <= 15.659\nsamples = 111\nvalue = '),
#  Text(122.77847682119204, 156.285, 'samples = 3\nvalue = '),
#  Text(131.64735099337747, 156.285, 'hr <= 99.5\nsamples = 108\nvalue = '),
#  Text(108.08940397350993, 142.695, 'bmi <= 20.876\nsamples = 82\nvalue = '),
#  Text(93.12317880794701, 129.10500000000002, 'hr <= 66.0\nsamples = 13\nvalue = '),
#  Text(88.6887417218543, 115.515, 'samples = 5\nvalue = '),
#  Text(97.55761589403973, 115.515, 'sysbp <= 172.5\nsamples = 8\nvalue = '),
#  Text(93.12317880794701, 101.925, 'samples = 5\nvalue = '),
#  Text(101.99205298013244, 101.925, 'samples = 3\nvalue = '),
#  Text(123.05562913907285, 129.10500000000002, 'los <= 2.5\nsamples = 69\nvalue = '),
#  Text(118.62119205298013, 115.515, 'samples = 5\nvalue = '),
#  Text(127.49006622516556, 115.515, 'los <= 7.5\nsamples = 64\nvalue = '),
#  Text(110.86092715231788, 101.925, 'hr <= 91.5\nsamples = 51\nvalue = '),
#  Text(99.77483443708608, 88.33500000000001, 'bmi <= 29.68\nsamples = 40\nvalue = '),
#  Text(90.90596026490066, 74.745, 'gender <= 0.5\nsamples = 29\nvalue = '),
#  Text(86.47152317880794, 61.155, 'hr <= 68.0\nsamples = 12\nvalue = '),
#  Text(82.03708609271523, 47.565, 'samples = 6\nvalue = '),
#  Text(90.90596026490066, 47.565, 'sysbp <= 144.0\nsamples = 6\nvalue = '),
#  Text(86.47152317880794, 33.974999999999994, 'samples = 3\nvalue = '),
#  Text(95.34039735099337, 33.974999999999994, 'samples = 3\nvalue = '),
#  Text(95.34039735099337, 61.155, 'samples = 17\nvalue = '),
#  Text(108.64370860927153, 74.745, 'hr <= 71.5\nsamples = 11\nvalue = '),
#  Text(104.2092715231788, 61.155, 'samples = 4\nvalue = '),
#  Text(113.07814569536424, 61.155, 'age <= 77.0\nsamples = 7\nvalue = '),
#  Text(108.64370860927153, 47.565, 'samples = 3\nvalue = '),
#  Text(117.51258278145696, 47.565, 'samples = 4\nvalue = '),
#  Text(121.94701986754967, 88.33500000000001, 'hr <= 95.5\nsamples = 11\nvalue = '),
#  Text(117.51258278145696, 74.745, 'samples = 5\nvalue = '),
#  Text(126.38145695364238, 74.745, 'sysbp <= 152.0\nsamples = 6\nvalue = '),
#  Text(121.94701986754967, 61.155, 'samples = 3\nvalue = '),
#  Text(130.8158940397351, 61.155, 'samples = 3\nvalue = '),
#  Text(144.11920529801324, 101.925, 'gender <= 0.5\nsamples = 13\nvalue = '),
#  Text(139.68476821192053, 88.33500000000001, 'diasbp <= 74.5\nsamples = 8\nvalue = '),
#  Text(135.2503311258278, 74.745, 'samples = 3\nvalue = '),
#  Text(144.11920529801324, 74.745, 'samples = 5\nvalue = '),
#  Text(148.55364238410596, 88.33500000000001, 'samples = 5\nvalue = '),
#  Text(155.20529801324503, 142.695, 'diasbp <= 63.0\nsamples = 26\nvalue = '),
#  Text(144.11920529801324, 129.10500000000002, 'diasbp <= 57.5\nsamples = 6\nvalue = '),
#  Text(139.68476821192053, 115.515, 'samples = 3\nvalue = '),
#  Text(148.55364238410596, 115.515, 'samples = 3\nvalue = '),
#  Text(166.2913907284768, 129.10500000000002, 'age <= 81.5\nsamples = 20\nvalue = '),
#  Text(157.42251655629138, 115.515, 'bmi <= 23.916\nsamples = 12\nvalue = '),
#  Text(152.98807947019867, 101.925, 'samples = 4\nvalue = '),
#  Text(161.8569536423841, 101.925, 'bmi <= 27.795\nsamples = 8\nvalue = '),
#  Text(157.42251655629138, 88.33500000000001, 'samples = 3\nvalue = '),
#  Text(166.2913907284768, 88.33500000000001, 'samples = 5\nvalue = '),
#  Text(175.16026490066224, 115.515, 'miord <= 0.5\nsamples = 8\nvalue = '),
#  Text(170.72582781456953, 101.925, 'samples = 4\nvalue = '),
#  Text(179.59470198675496, 101.925, 'samples = 4\nvalue = '),
#  Text(222.83046357615893, 183.465, 'sysbp <= 84.0\nsamples = 118\nvalue = '),
#  Text(218.39602649006622, 169.875, 'samples = 3\nvalue = '),
#  Text(227.26490066225165, 169.875, 'age <= 67.5\nsamples = 115\nvalue = '),
#  Text(201.76688741721853, 156.285, 'miord <= 0.5\nsamples = 35\nvalue = '),
#  Text(192.8980132450331, 142.695, 'diasbp <= 102.5\nsamples = 23\nvalue = '),
#  Text(188.46357615894038, 129.10500000000002, 'hr <= 92.5\nsamples = 16\nvalue = '),
#  Text(184.02913907284767, 115.515, 'samples = 9\nvalue = '),
#  Text(192.8980132450331, 115.515, 'afb <= 0.5\nsamples = 7\nvalue = '),
#  Text(188.46357615894038, 101.925, 'samples = 4\nvalue = '),
#  Text(197.3324503311258, 101.925, 'samples = 3\nvalue = '),
#  Text(197.3324503311258, 129.10500000000002, 'samples = 7\nvalue = '),
#  Text(210.63576158940396, 142.695, 'diasbp <= 58.5\nsamples = 12\nvalue = '),
#  Text(206.20132450331124, 129.10500000000002, 'samples = 3\nvalue = '),
#  Text(215.0701986754967, 129.10500000000002, 'gender <= 0.5\nsamples = 9\nvalue = '),
#  Text(210.63576158940396, 115.515, 'hr <= 102.0\nsamples = 6\nvalue = '),
#  Text(206.20132450331124, 101.925, 'samples = 3\nvalue = '),
#  Text(215.0701986754967, 101.925, 'samples = 3\nvalue = '),
#  Text(219.5046357615894, 115.515, 'samples = 3\nvalue = '),
#  Text(252.76291390728477, 156.285, 'sho <= 0.5\nsamples = 80\nvalue = '),
#  Text(241.67682119205298, 142.695, 'bmi <= 22.206\nsamples = 74\nvalue = '),
#  Text(232.80794701986756, 129.10500000000002, 'afb <= 0.5\nsamples = 17\nvalue = '),
#  Text(228.37350993377484, 115.515, 'sysbp <= 117.0\nsamples = 13\nvalue = '),
#  Text(223.93907284768213, 101.925, 'samples = 3\nvalue = '),
#  Text(232.80794701986756, 101.925, 'miord <= 0.5\nsamples = 10\nvalue = '),
#  Text(228.37350993377484, 88.33500000000001, 'samples = 5\nvalue = '),
#  Text(237.24238410596027, 88.33500000000001, 'samples = 5\nvalue = '),
#  Text(237.24238410596027, 115.515, 'samples = 4\nvalue = '),
#  Text(250.5456953642384, 129.10500000000002, 'diasbp <= 48.0\nsamples = 57\nvalue = '),
#  Text(246.1112582781457, 115.515, 'samples = 4\nvalue = '),
#  Text(254.98013245033113, 115.515, 'bmi <= 22.476\nsamples = 53\nvalue = '),
#  Text(250.5456953642384, 101.925, 'samples = 3\nvalue = '),
#  Text(259.4145695364238, 101.925, 'diasbp <= 121.0\nsamples = 50\nvalue = '),
#  Text(254.98013245033113, 88.33500000000001, 'sysbp <= 128.5\nsamples = 47\nvalue = '),
#  Text(239.45960264900663, 74.745, 'hr <= 68.5\nsamples = 12\nvalue = '),
#  Text(235.0251655629139, 61.155, 'samples = 3\nvalue = '),
#  Text(243.89403973509934, 61.155, 'mitype <= 0.5\nsamples = 9\nvalue = '),
#  Text(239.45960264900663, 47.565, 'los <= 5.0\nsamples = 6\nvalue = '),
#  Text(235.0251655629139, 33.974999999999994, 'samples = 3\nvalue = '),
#  Text(243.89403973509934, 33.974999999999994, 'samples = 3\nvalue = '),
#  Text(248.32847682119206, 47.565, 'samples = 3\nvalue = '),
#  Text(270.5006622516556, 74.745, 'sysbp <= 137.5\nsamples = 35\nvalue = '),
#  Text(261.6317880794702, 61.155, 'age <= 75.0\nsamples = 6\nvalue = '),
#  Text(257.1973509933775, 47.565, 'samples = 3\nvalue = '),
#  Text(266.0662251655629, 47.565, 'samples = 3\nvalue = '),
#  Text(279.36953642384105, 61.155, 'bmi <= 23.729\nsamples = 29\nvalue = '),
#  Text(274.93509933774834, 47.565, 'samples = 3\nvalue = '),
#  Text(283.80397350993377, 47.565, 'hr <= 90.5\nsamples = 26\nvalue = '),
#  Text(272.71788079470195, 33.974999999999994, 'sysbp <= 162.5\nsamples = 11\nvalue = '),
#  Text(268.28344370860924, 20.38499999999999, 'diasbp <= 75.0\nsamples = 8\nvalue = '),
#  Text(263.8490066225165, 6.7949999999999875, 'samples = 5\nvalue = '),
#  Text(272.71788079470195, 6.7949999999999875, 'samples = 3\nvalue = '),
#  Text(277.15231788079467, 20.38499999999999, 'samples = 3\nvalue = '),
#  Text(294.8900662251656, 33.974999999999994, 'gender <= 0.5\nsamples = 15\nvalue = '),
#  Text(286.02119205298015, 20.38499999999999, 'los <= 5.5\nsamples = 7\nvalue = '),
#  Text(281.5867549668874, 6.7949999999999875, 'samples = 4\nvalue = '),
#  Text(290.45562913907287, 6.7949999999999875, 'samples = 3\nvalue = '),
#  Text(303.758940397351, 20.38499999999999, 'diasbp <= 106.0\nsamples = 8\nvalue = '),
#  Text(299.3245033112583, 6.7949999999999875, 'samples = 5\nvalue = '),
#  Text(308.1933774834437, 6.7949999999999875, 'samples = 3\nvalue = '),
#  Text(263.8490066225165, 88.33500000000001, 'samples = 3\nvalue = '),
#  Text(263.8490066225165, 142.695, 'bmi <= 27.564\nsamples = 6\nvalue = '),
#  Text(259.4145695364238, 129.10500000000002, 'samples = 3\nvalue = '),
#  Text(268.28344370860924, 129.10500000000002, 'samples = 3\nvalue = '),
#  Text(307.0847682119205, 197.055, 'sho <= 0.5\nsamples = 67\nvalue = '),
#  Text(302.6503311258278, 183.465, 'afb <= 0.5\nsamples = 62\nvalue = '),
#  Text(288.2384105960265, 169.875, 'diasbp <= 44.0\nsamples = 49\nvalue = '),
#  Text(277.15231788079467, 156.285, 'cvd <= 0.5\nsamples = 6\nvalue = '),
#  Text(272.71788079470195, 142.695, 'samples = 3\nvalue = '),
#  Text(281.5867549668874, 142.695, 'samples = 3\nvalue = '),
#  Text(299.3245033112583, 156.285, 'sysbp <= 124.0\nsamples = 43\nvalue = '),
#  Text(290.45562913907287, 142.695, 'diasbp <= 67.5\nsamples = 9\nvalue = '),
#  Text(286.02119205298015, 129.10500000000002, 'sysbp <= 117.0\nsamples = 6\nvalue = '),
#  Text(281.5867549668874, 115.515, 'samples = 3\nvalue = '),
#  Text(290.45562913907287, 115.515, 'samples = 3\nvalue = '),
#  Text(294.8900662251656, 129.10500000000002, 'samples = 3\nvalue = '),
#  Text(308.1933774834437, 142.695, 'los <= 2.5\nsamples = 34\nvalue = '),
#  Text(303.758940397351, 129.10500000000002, 'samples = 4\nvalue = '),
#  Text(312.62781456953644, 129.10500000000002, 'hr <= 69.5\nsamples = 30\nvalue = '),
#  Text(308.1933774834437, 115.515, 'samples = 5\nvalue = '),
#  Text(317.06225165562915, 115.515, 'sysbp <= 153.5\nsamples = 25\nvalue = '),
#  Text(308.1933774834437, 101.925, 'hr <= 104.5\nsamples = 16\nvalue = '),
#  Text(303.758940397351, 88.33500000000001, 'bmi <= 22.724\nsamples = 11\nvalue = '),
#  Text(299.3245033112583, 74.745, 'samples = 3\nvalue = '),
#  Text(308.1933774834437, 74.745, 'bmi <= 24.224\nsamples = 8\nvalue = '),
#  Text(303.758940397351, 61.155, 'samples = 3\nvalue = '),
#  Text(312.62781456953644, 61.155, 'samples = 5\nvalue = '),
#  Text(312.62781456953644, 88.33500000000001, 'samples = 5\nvalue = '),
#  Text(325.9311258278146, 101.925, 'bmi <= 22.758\nsamples = 9\nvalue = '),
#  Text(321.49668874172187, 88.33500000000001, 'samples = 5\nvalue = '),
#  Text(330.3655629139073, 88.33500000000001, 'samples = 4\nvalue = '),
#  Text(317.06225165562915, 169.875, 'sysbp <= 105.5\nsamples = 13\nvalue = '),
#  Text(312.62781456953644, 156.285, 'samples = 4\nvalue = '),
#  Text(321.49668874172187, 156.285, 'hr <= 90.0\nsamples = 9\nvalue = '),
#  Text(317.06225165562915, 142.695, 'samples = 4\nvalue = '),
#  Text(325.9311258278146, 142.695, 'samples = 5\nvalue = '),
#  Text(311.5192052980132, 183.465, 'samples = 5\nvalue = ')]

# %%
predict_outcomes = estimator.predict(X)
surv_funcs = estimator.predict_survival_function(X.iloc[:5])

for fn in surv_funcs:
    plt.step(fn.x, fn(fn.x), where="post")
plt.ylim(0,1)
plt.show()

# %%
chf_funcs = estimator.predict_cumulative_hazard_function(X.iloc[:5])

for fn in chf_funcs:
    plt.step(fn.x, fn(fn.x), where="post")
plt.ylim(0,1)
plt.show()

# %%
X,y = load_gbsg2()
grade_str = X.loc[:, "tgrade"].astype(object).values[:,np.newaxis]
grade_num = OrdinalEncoder(categories=[["I", "II", "III"]]).fit_transform(grade_str)
X_no_grade = X.drop("tgrade",axis=1)
Xt = OneHotEncoder().fit_transform(X_no_grade)
Xt.loc[:, "tgrade"] = grade_num


random_state = 20
X_train, X_test,y_train,y_test = train_test_split(Xt, y, test_size=0.25, random_state=random_state)

rsf = RandomSurvivalForest(n_estimators = 1000, 
                           min_samples_split = 10,
                           min_samples_leaf = 15,
                           max_features = "sqrt",
                           n_jobs = -1,
                           random_state = random_state)

rsf.fit(X_train,y_train)
rsf.score(X_test, y_test)
# Out:
# 0.6759696016771488

# %%
X_test_sorted = X_test.sort_values(by=["pnodes", "age"])
X_test_sel = pd.concat((X_test_sorted.head(3), X_test_sorted.tail(3)))
X_test_sel
# Out:
#       age  estrec  horTh=yes  menostat=Post  pnodes  progrec  tsize  tgrade
# 119  33.0     0.0        0.0            0.0     1.0     26.0   35.0     2.0
# 574  34.0    37.0        0.0            0.0     1.0      0.0   40.0     2.0
# 421  36.0    14.0        0.0            0.0     1.0     76.0   36.0     1.0
# 24   65.0    64.0        0.0            1.0    26.0      2.0   70.0     2.0
# 8    80.0    59.0        0.0            1.0    30.0      0.0   39.0     1.0
# 226  72.0  1091.0        1.0            1.0    36.0      2.0   34.0     2.0

# %%
pd.Series(rsf.predict(X_test_sel))
# Out:
# 0     91.477609
# 1    102.897552
# 2     75.883786
# 3    170.502092
# 4    171.210066
# 5    148.691835
# dtype: float64

# %%
surv = rsf.predict_survival_function(X_test_sel, return_array=True)
for i,s in enumerate(surv):
    plt.step(rsf.event_times_,s, where="post", label=str(i))
plt.ylabel("Survivalprobability")
plt.xlabel("Timeindays")
plt.legend()
plt.grid(True)

# %%
surv = rsf.predict_cumulative_hazard_function(X_test_sel, return_array=True)
for i,s in enumerate(surv):
    plt.step(rsf.event_times_,s, where="post", label=str(i))
plt.ylabel("Cumulativehazard")
plt.xlabel("Timeindays")
plt.legend()
plt.grid(True)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sksurv.datasets import load_whas500

X, y = load_whas500()

# %%
X.head(10).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_51139_" ><thead>    <tr>        <th class="col_heading level0 col0" >afb</th>        <th class="col_heading level0 col1" >age</th>        <th class="col_heading level0 col2" >av3</th>        <th class="col_heading level0 col3" >bmi</th>        <th class="col_heading level0 col4" >chf</th>        <th class="col_heading level0 col5" >cvd</th>        <th class="col_heading level0 col6" >diasbp</th>        <th class="col_heading level0 col7" >gender</th>        <th class="col_heading level0 col8" >hr</th>        <th class="col_heading level0 col9" >los</th>        <th class="col_heading level0 col10" >miord</th>        <th class="col_heading level0 col11" >mitype</th>        <th class="col_heading level0 col12" >sho</th>        <th class="col_heading level0 col13" >sysbp</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_51139_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_51139_row0_col1" class="data row0 col1" >83.000000</td>
#                         <td id="T_51139_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_51139_row0_col3" class="data row0 col3" >25.540510</td>
#                         <td id="T_51139_row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_51139_row0_col5" class="data row0 col5" >1</td>
#                         <td id="T_51139_row0_col6" class="data row0 col6" >78.000000</td>
#                         <td id="T_51139_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_51139_row0_col8" class="data row0 col8" >89.000000</td>
#                         <td id="T_51139_row0_col9" class="data row0 col9" >5.000000</td>
#                         <td id="T_51139_row0_col10" class="data row0 col10" >1</td>
#                         <td id="T_51139_row0_col11" class="data row0 col11" >0</td>
#                         <td id="T_51139_row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_51139_row0_col13" class="data row0 col13" >152.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_51139_row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_51139_row1_col1" class="data row1 col1" >49.000000</td>
#                         <td id="T_51139_row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_51139_row1_col3" class="data row1 col3" >24.023980</td>
#                         <td id="T_51139_row1_col4" class="data row1 col4" >0</td>
#                         <td id="T_51139_row1_col5" class="data row1 col5" >1</td>
#                         <td id="T_51139_row1_col6" class="data row1 col6" >60.000000</td>
#                         <td id="T_51139_row1_col7" class="data row1 col7" >0</td>
#                         <td id="T_51139_row1_col8" class="data row1 col8" >84.000000</td>
#                         <td id="T_51139_row1_col9" class="data row1 col9" >5.000000</td>
#                         <td id="T_51139_row1_col10" class="data row1 col10" >0</td>
#                         <td id="T_51139_row1_col11" class="data row1 col11" >1</td>
#                         <td id="T_51139_row1_col12" class="data row1 col12" >0</td>
#                         <td id="T_51139_row1_col13" class="data row1 col13" >120.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_51139_row2_col0" class="data row2 col0" >0</td>
#                         <td id="T_51139_row2_col1" class="data row2 col1" >70.000000</td>
#                         <td id="T_51139_row2_col2" class="data row2 col2" >0</td>
#                         <td id="T_51139_row2_col3" class="data row2 col3" >22.142900</td>
#                         <td id="T_51139_row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_51139_row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_51139_row2_col6" class="data row2 col6" >88.000000</td>
#                         <td id="T_51139_row2_col7" class="data row2 col7" >1</td>
#                         <td id="T_51139_row2_col8" class="data row2 col8" >83.000000</td>
#                         <td id="T_51139_row2_col9" class="data row2 col9" >5.000000</td>
#                         <td id="T_51139_row2_col10" class="data row2 col10" >0</td>
#                         <td id="T_51139_row2_col11" class="data row2 col11" >1</td>
#                         <td id="T_51139_row2_col12" class="data row2 col12" >0</td>
#                         <td id="T_51139_row2_col13" class="data row2 col13" >147.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_51139_row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_51139_row3_col1" class="data row3 col1" >70.000000</td>
#                         <td id="T_51139_row3_col2" class="data row3 col2" >0</td>
#                         <td id="T_51139_row3_col3" class="data row3 col3" >26.631870</td>
#                         <td id="T_51139_row3_col4" class="data row3 col4" >1</td>
#                         <td id="T_51139_row3_col5" class="data row3 col5" >1</td>
#                         <td id="T_51139_row3_col6" class="data row3 col6" >76.000000</td>
#                         <td id="T_51139_row3_col7" class="data row3 col7" >0</td>
#                         <td id="T_51139_row3_col8" class="data row3 col8" >65.000000</td>
#                         <td id="T_51139_row3_col9" class="data row3 col9" >10.000000</td>
#                         <td id="T_51139_row3_col10" class="data row3 col10" >0</td>
#                         <td id="T_51139_row3_col11" class="data row3 col11" >1</td>
#                         <td id="T_51139_row3_col12" class="data row3 col12" >0</td>
#                         <td id="T_51139_row3_col13" class="data row3 col13" >123.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_51139_row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_51139_row4_col1" class="data row4 col1" >70.000000</td>
#                         <td id="T_51139_row4_col2" class="data row4 col2" >0</td>
#                         <td id="T_51139_row4_col3" class="data row4 col3" >24.412550</td>
#                         <td id="T_51139_row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_51139_row4_col5" class="data row4 col5" >1</td>
#                         <td id="T_51139_row4_col6" class="data row4 col6" >85.000000</td>
#                         <td id="T_51139_row4_col7" class="data row4 col7" >0</td>
#                         <td id="T_51139_row4_col8" class="data row4 col8" >63.000000</td>
#                         <td id="T_51139_row4_col9" class="data row4 col9" >6.000000</td>
#                         <td id="T_51139_row4_col10" class="data row4 col10" >0</td>
#                         <td id="T_51139_row4_col11" class="data row4 col11" >1</td>
#                         <td id="T_51139_row4_col12" class="data row4 col12" >0</td>
#                         <td id="T_51139_row4_col13" class="data row4 col13" >135.000000</td>
#             </tr>
#             <tr>
#                                 <td id="T_51139_row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_51139_row5_col1" class="data row5 col1" >70.000000</td>
#                         <td id="T_51139_row5_col2" class="data row5 col2" >1</td>
#                         <td id="T_51139_row5_col3" class="data row5 col3" >23.242360</td>
#                         <td id="T_51139_row5_col4" class="data row5 col4" >0</td>
#                         <td id="T_51139_row5_col5" class="data row5 col5" >1</td>
#                         <td id="T_51139_row5_col6" class="data row5 col6" >54.000000</td>
#                         <td id="T_51139_row5_col7" class="data row5 col7" >0</td>
#                         <td id="T_51139_row5_col8" class="data row5 col8" >76.000000</td>
#                         <td id="T_51139_row5_col9" class="data row5 col9" >1.000000</td>

# %%
y[:10]
# Out:
# array([(False, 2.178e+03), (False, 2.172e+03), (False, 2.190e+03),
#        ( True, 2.970e+02), (False, 2.131e+03), ( True, 1.000e+00),
#        (False, 2.122e+03), ( True, 1.496e+03), ( True, 9.200e+02),
#        (False, 2.175e+03)], dtype=[('fstat', '?'), ('lenfol', '<f8')])

# %%
df_y = pd.DataFrame(data={'time': [y[i][1] for i in range(len(y))], 'event': [y[i][0] for i in range(len(y))]})
df_y[:10].style.hide_index().highlight_min('event', color='lightgreen')
# Out:
# <style  type="text/css" >
# #T_34e3c_row0_col1,#T_34e3c_row1_col1,#T_34e3c_row2_col1,#T_34e3c_row4_col1,#T_34e3c_row6_col1,#T_34e3c_row9_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_34e3c_" ><thead>    <tr>        <th class="col_heading level0 col0" >time</th>        <th class="col_heading level0 col1" >event</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_34e3c_row0_col0" class="data row0 col0" >2178.000000</td>
#                         <td id="T_34e3c_row0_col1" class="data row0 col1" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_34e3c_row1_col0" class="data row1 col0" >2172.000000</td>
#                         <td id="T_34e3c_row1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_34e3c_row2_col0" class="data row2 col0" >2190.000000</td>
#                         <td id="T_34e3c_row2_col1" class="data row2 col1" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_34e3c_row3_col0" class="data row3 col0" >297.000000</td>
#                         <td id="T_34e3c_row3_col1" class="data row3 col1" >True</td>
#             </tr>
#             <tr>
#                                 <td id="T_34e3c_row4_col0" class="data row4 col0" >2131.000000</td>
#                         <td id="T_34e3c_row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_34e3c_row5_col0" class="data row5 col0" >1.000000</td>
#                         <td id="T_34e3c_row5_col1" class="data row5 col1" >True</td>
#             </tr>
#             <tr>
#                                 <td id="T_34e3c_row6_col0" class="data row6 col0" >2122.000000</td>
#                         <td id="T_34e3c_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                                 <td id="T_34e3c_row7_col0" class="data row7 col0" >1496.000000</td>
#                         <td id="T_34e3c_row7_col1" class="data row7 col1" >True</td>
#             </tr>
#             <tr>
#                                 <td id="T_34e3c_row8_col0" class="data row8 col0" >920.000000</td>
#                         <td id="T_34e3c_row8_col1" class="data row8 col1" >True</td>
#             </tr>
#             <tr>
#                                 <td id="T_34e3c_row9_col0" class="data row9 col0" >2175.000000</td>
#                         <td id="T_34e3c_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# One of the main challenges of survival analysis is right censoring, i.e., by the end of the study, the event of interest (for example, in medicine 'death of a patient' or in this dataset 'recurrence of cancer') has only occurred for a subset of the observations.
#
# The right censoring in this dataset is given by the column named 'event' and it's a variable which can take value 'True' if the patient had a recurrence of cancer or 'False' if the patient is recurrence free at the indicated time (right-censored samples).
#
# Let's see how many right-censored samples do we have.

# %%
print(f'Number of samples: {len(df_y)}')
print(f'Number of right censored samples: {len(df_y.query("event == False"))}')
print(f'Percentage of right censored samples: {100*len(df_y.query("event == False"))/len(df_y):.1f}%')
# Out:
# Number of samples: 500
# Number of right censored samples: 285
# Percentage of right censored samples: 57.0%

# %% [markdown]
# There are 387 patients (56.4%) who were right censored (recurrence free) at the end of the study.
#
# Let's divide our dataset in training and test sets.

# %%
from sklearn.model_selection import train_test_split

X_trn, X_test, y_trn, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

print(f'Number of training samples: {len(y_trn)}')
print(f'Number of test samples: {len(y_test)}')
# Out:
# Number of training samples: 350
# Number of test samples: 150

# %% [markdown]
# We divide the features/covariates into continuous and categorical.

# %%
scaling_cols = [c for c in X.columns if X[c].dtype.kind in ['i', 'f']]
cat_cols     = [c for c in X.columns if X[c].dtype.kind not in ["i", "f"]]

# %% [markdown]
# We use ordinal encoding for categorical features/covariates and standard scaling for continuous features/covariates.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler

preprocessor = ColumnTransformer(
    [('cat-preprocessor', OrdinalEncoder(), cat_cols),
    ('standard-scaler', StandardScaler(), scaling_cols)],
    remainder='passthrough', sparse_threshold=0)

# %%
from sksurv.ensemble import RandomSurvivalForest
from sklearn.pipeline import make_pipeline
from sksurv.linear_model import CoxPHSurvivalAnalysis
from sksurv.metrics import concordance_index_censored
from scipy.stats import reciprocal
from sklearn.model_selection import RandomizedSearchCV

rsf = make_pipeline(preprocessor, RandomSurvivalForest(random_state=42))
rsf.fit(X_trn, y_trn)
ci_rsf = concordance_index_censored(y_test["fstat"], y_test["lenfol"], rsf.predict(X_test))
print(f'The c-index of Random Survival Forest is given by {ci_rsf[0]:.3f}')
# Out:
# The c-index of Random Survival Forest is given by 0.747

# %%
class reciprocal_int:
    def __init__(self, a, b):
        self._distribution = reciprocal(a, b)

    def rvs(self, *args, **kwargs):
        return self._distribution.rvs(*args, **kwargs).astype(int)

param_distributions1 = {
    'randomsurvivalforest__max_features': reciprocal_int(3, 8),
    'randomsurvivalforest__max_depth': reciprocal_int(5, 50),
    'randomsurvivalforest__min_samples_leaf': reciprocal_int(1, 40),
}

model_random_search = RandomizedSearchCV(
    rsf, param_distributions=param_distributions1, n_iter=50, n_jobs=-1, cv=3, random_state=0)
model_random_search.fit(X_trn, y_trn)

print(
    f"The c-index of random survival forest using a {model_random_search.__class__.__name__} is "
    f"{model_random_search.score(X_test, y_test):.3f}")
print(
    f"The best set of parameters is: {model_random_search.best_params_}"
)
# Out:
# The c-index of random survival forest using a RandomizedSearchCV is 0.756
# The best set of parameters is: {'randomsurvivalforest__max_depth': 6, 'randomsurvivalforest__max_features': 5, 'randomsurvivalforest__min_samples_leaf': 1}

# %%
max_depth = model_random_search.best_params_['randomsurvivalforest__max_depth']
max_features = model_random_search.best_params_['randomsurvivalforest__max_features']
min_samples_leaf = model_random_search.best_params_['randomsurvivalforest__min_samples_leaf']

# %%
rsf_best = make_pipeline(preprocessor, RandomSurvivalForest(random_state=42, max_depth=max_depth, max_features=max_features, min_samples_leaf=min_samples_leaf))
rsf_best.fit(X_trn, y_trn)
ci_rsf = concordance_index_censored(y_test["fstat"], y_test["lenfol"], rsf_best.predict(X_test))
print(f'The c-index of Random Survival Forest is given by {ci_rsf[0]:.3f}')
# Out:
# The c-index of Random Survival Forest is given by 0.756

# %%
from eli5.sklearn import PermutationImportance
perm = PermutationImportance(rsf.steps[-1][1], n_iter=100).fit(preprocessor.fit_transform(X_trn),y_trn)

data = perm.results_
data = pd.DataFrame(data, columns=X_trn.columns)
meds = data.median()
meds = meds.sort_values(ascending=False)
data = data[meds.index]

# %%
fig, ax = plt.subplots(figsize=(10,7))
data.boxplot(ax=ax)
ax.set_title('Feature Importances')
plt.show()

# %%
eli5.show_weights(perm, feature_names = X.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1188
#
#                     &plusmn; 0.0228
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 hr
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0394
#
#                     &plusmn; 0.0109
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 av3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0370
#
#                     &plusmn; 0.0073
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mitype
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.65%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0341
#
#                     &plusmn; 0.0071
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 los
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0265
#
#                     &plusmn; 0.0074
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 miord
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0203
#
#                     &plusmn; 0.0043
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sysbp
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.80%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0174
#
#                     &plusmn; 0.0036
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sho
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0089
#
#                     &plusmn; 0.0025
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 chf
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0083
#
#                     &plusmn; 0.0031
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 diasbp
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0074
#
#                     &plusmn; 0.0025
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 cvd
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0049
#
#                     &plusmn; 0.0022
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 afb
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0041
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 bmi
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.22%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0038
#
#                     &plusmn; 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 gender
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
cox = make_pipeline(preprocessor, CoxPHSurvivalAnalysis())
cox.fit(X_trn, y_trn)

ci_cox = concordance_index_censored(y_test["fstat"], y_test["lenfol"], cox.predict(X_test))
print(f'The c-index of Cox is given by {ci_cox[0]:.3f}')
# Out:
# The c-index of Cox is given by 0.812

# %%
np.random.seed(0)
seeds = np.random.permutation(1000)[:25]

param_distributions = {
    'coxphsurvivalanalysis__alpha': reciprocal(0.1, 100),
}

# alpha = model_random_search.best_params_['coxphsurvivalanalysis__alpha']
cox_scores = []
rsf_scores = []
for _seed in seeds:
    X_trn, X_test, y_trn, y_test = train_test_split(X, y, random_state=_seed)
  
    cox_best = make_pipeline(preprocessor, CoxPHSurvivalAnalysis())
    cox_best.fit(X_trn, y_trn)
    ci_cox = concordance_index_censored(y_test["fstat"], y_test["lenfol"], cox_best.predict(X_test))
    cox_scores.append(ci_cox[0])

    rsf = make_pipeline(preprocessor, RandomSurvivalForest(n_estimators=1000, 
                                                           min_samples_split=10,
                                                           min_samples_leaf=15,
                                                           max_features="sqrt",
                                                           n_jobs=-1,
                                                           random_state=42))
    rsf.fit(X_trn, y_trn)
    ci_rsf = concordance_index_censored(y_test["fstat"], y_test["lenfol"], rsf.predict(X_test))
    rsf_scores.append(ci_rsf[0])

# %%
print(f'Cox proportional hazards model: Mean c-index: {np.mean(cox_scores):.3f}, standard deviation: {np.std(cox_scores):.3f}')
print(f'Random Survival Forest model: Mean c-index: {np.mean(rsf_scores):.3f}, standard deviation: {np.std(rsf_scores):.3f}')
# Out:
# Cox proportional hazards model: Mean c-index: 0.765, standard deviation: 0.028
# Random Survival Forest model: Mean c-index: 0.762, standard deviation: 0.023

# %%
rsf = RandomSurvivalForest(n_estimators=1000,
                            min_samples_split=10,
                            min_samples_leaf=15,
                            max_features="sqrt",
                            n_jobs=-1,
                            random_state=random_state)
rsf.fit(X_train,y_train)
# Out:
# RandomSurvivalForest(min_samples_leaf=5, min_samples_split=10,
#                      n_estimators=1000, n_jobs=-1, random_state=20)

# %%
pd.Series(rsf_best.predict(X_test))
# Out:
# 0        9.684591
# 1      100.904334
# 2        5.826946
# 3        4.448846
# 4       32.353021
#           ...
# 120     31.352599
# 121     21.568554
# 122     48.631920
# 123     62.871306
# 124     83.598534
# Length: 125, dtype: float64

# %%
rsf_best.score(X_test, y_test)
# Out:
# 0.8434922550794609

# %%
X_test
# Out:
#     afb   age av3       bmi chf cvd  diasbp gender     hr   los miord mitype  \
# 282   0  57.0   0  25.82748   0   1    70.0      0   93.0   4.0     0      0
# 396   0  84.0   0  23.24075   0   1    50.0      1  100.0  12.0     0      0
# 308   0  59.0   0  28.62989   0   0    88.0      0   72.0   4.0     0      0
# 333   0  45.0   0  37.65760   0   0   102.0      0   68.0   4.0     0      1
# 449   0  80.0   0  22.88965   0   1    84.0      0   99.0   5.0     1      0
# ..   ..   ...  ..       ...  ..  ..     ...    ...    ...   ...   ...    ...
# 188   0  80.0   0  19.65076   0   1    82.0      1   64.0   8.0     0      1
# 137   0  58.0   0  21.28707   0   0    67.0      0   90.0   8.0     1      1
# 226   0  58.0   0  34.43664   0   1    11.0      0   89.0   5.0     0      1
# 58    0  84.0   0  23.56005   0   1    66.0      1  135.0   2.0     1      0
# 358   0  65.0   0  16.99342   1   1   105.0      1  144.0   8.0     1      0
#
#     sho  sysbp
# 282   0  130.0
# 396   0   85.0
# 308   0  140.0
# 333   0  155.0
# 449   0  179.0
# ..   ..    ...
# 188   0  189.0
# 137   0  116.0
# 226   0  177.0
# 58    0  111.0
# 358   0  202.0
#
# [125 rows x 14 columns]

# %%
X_test_sorted = X_test.sort_values(by=["age", "diasbp"])
X_test_sel = pd.concat((X_test_sorted.head(3), X_test_sorted.tail(3)))
X_test_sel
# Out:
#     afb   age av3       bmi chf cvd  diasbp gender    hr  los miord mitype  \
# 110   0  30.0   0  29.85998   0   0   102.0      0  90.0  2.0     0      1
# 302   0  36.0   0  31.64232   0   0    20.0      0  98.0  1.0     1      0
# 333   0  45.0   0  37.65760   0   0   102.0      0  68.0  4.0     0      1
# 36    0  92.0   0  13.04546   0   0    74.0      1  70.0  6.0     0      0
# 234   1  92.0   0  27.43890   0   0    75.0      0  72.0  1.0     0      1
# 354   0  95.0   0  27.98863   1   1    62.0      0  80.0  1.0     1      1
#
#     sho  sysbp
# 110   0  175.0
# 302   0  132.0
# 333   0  155.0
# 36    0  154.0
# 234   0  114.0
# 354   0  111.0

# %%
pd.Series(rsf_best.predict(X_test_sel))
# Out:
# 0     10.525298
# 1     19.962934
# 2      4.448846
# 3    117.365440
# 4    115.817083
# 5    129.644962
# dtype: float64

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt
import numpy as np
from skimage import measure


# Set up mesh
n = 100 

x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
z = np.linspace(-3,3,n)
X, Y, Z =  np.meshgrid(x, y, z)

# Create cardioid function 
def f_heart(x,y,z):
    F = 320 * ((-x**2 * z**3 -9*y**2 * z**3/80) +
               (x**2 + 9*y**2/4 + z**2-1)**3)
    return F

# Obtain value to at every point in mesh
vol = f_heart(X,Y,Z) 

# Extract a 2D surface mesh from a 3D volume (F=0)
verts, faces, normals, values = measure.marching_cubes_lewiner(vol, 0,  spacing=(0.1, 0.1, 0.1))


# Create a 3D figure
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_trisurf(verts[:, 0], verts[:,1], faces, verts[:, 2],
                cmap='Spectral', lw=1)

# Change the angle of view and title
ax.view_init(15, -15)

# ax.set_title(u"Made with ❤ (and Python)", fontsize=15) # if you have Python 3
ax.set_title("Made with <3 (and Python)", fontsize=15)

# Show me some love ^^
plt.show()
# Out:
# C:\Users\Renan\AppData\Local\Temp/ipykernel_4028/1855523563.py:25: FutureWarning: marching_cubes_lewiner is deprecated in favor of marching_cubes. marching_cubes_lewiner will be removed in version 0.19
#   verts, faces, normals, values = measure.marching_cubes_lewiner(vol, 0,  spacing=(0.1, 0.1, 0.1))
